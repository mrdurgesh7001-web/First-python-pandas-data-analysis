# %% [markdown]
# # Load the data

# %%
# Load the data
import pandas as pd
df = pd.read_csv(r"C:\Documents\Python Learning\Python Pandas\amazon sales Analysis\amazon.csv")
df.head(10)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 5  B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 6  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 7  B08DDRGWTJ             MI Usb Type-C Cable Smartphone (Black)
# 8  B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
# 9  B082LZGK39  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# ...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %%
# Gie how many's row and columns and  which columns contain missing value
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1463 non-null   object
#  1   product_name         1464 non-null   object
#  2   category             1462 non-null   object
#  3   discounted_price     1464 non-null   object
#  4   actual_price         1464 non-null   object
#  5   discount_percentage  1464 non-null   object
#  6   rating               1464 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1459 non-null   object
#  9   user_id              1462 non-null   object
#  10  user_name            1462 non-null   object
#  11  review_id            1464 non-null   object
#  12  review_title         1459 non-null   object
#  13  review_content       1460 non-null   object
#  14  img_link             1460 non-null   object
# ...

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1463                                               1464
# unique        1350                                               1336
# top     B08CF3B7N1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1462             1464
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  231               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1464                1464   1464         1463
# unique          449                  92     26         1143
# ...

# %%
# How many missing values in each columns
df.isnull().sum()
# Out:
# product_id             2
# product_name           1
# category               3
# discounted_price       1
# actual_price           1
# discount_percentage    1
# rating                 1
# rating_count           2
# about_product          6
# user_id                3
# user_name              3
# review_id              1
# review_title           6
# review_content         5
# img_link               5
# product_link           9
# dtype: int64

# %%
# Give in percentage How many missing values in each columns

df.isnull().sum() /len(df)*100
# Out:
# product_id             0.136519
# product_name           0.068259
# category               0.204778
# discounted_price       0.068259
# actual_price           0.068259
# discount_percentage    0.068259
# rating                 0.068259
# rating_count           0.136519
# about_product          0.409556
# user_id                0.204778
# user_name              0.204778
# review_id              0.068259
# review_title           0.409556
# review_content         0.341297
# img_link               0.341297
# product_link           0.614334
# dtype: float64

# %%
# how many duplicates rows in csv file
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#How many times Each product id's appears
df["product_id"].value_counts().head(10)
# Out:
# product_id
# B08CF3B7N1    3
# B08Y1TFSP6    3
# B09YLXYP7Y    3
# B085DTN6R2    3
# B09KLVMZ3B    3
# B083342NKJ    3
# B096MSW6CT    3
# B09C6HXFC1    3
# B098NS6PVG    3
# B09W5XR9RT    3
# Name: count, dtype: int64

# %%
# Checking product id "B08CF3B7N1" 
df[df["product_id"]=="B08CF3B7N1"]
# Out:
#      product_id                                       product_name  \
# 4    B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 393  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 632  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                               category discounted_price  \
# 4    Computers&Accessories|Accessories&Peripherals|...             ₹154
# 393  Computers&Accessories|Accessories&Peripherals|...             ₹154
# 632  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#     actual_price discount_percentage rating rating_count  \
# 4           ₹399                 61%    4.2       16,905
# 393         ₹399                 61%    4.2       16,905
# 632         ₹399                 61%    4.2       16,905
#
#                                          about_product  \
# 4    [CHARGE & SYNC FUNCTION]- This cable comes wit...
# 393  [CHARGE & SYNC FUNCTION]- This cable comes wit...
# ...

# %%
# how many each product id's apperas reapeated how many times 
df["product_id"].value_counts().value_counts()
# Out:
# count
# 1    1259
# 2      69
# 3      22
# Name: count, dtype: int64

# %%
# Delete duplicte rows
df.drop_duplicates()
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
# Give product Id's that appears 2 time
df["product_id"].value_counts()[df["product_id"].value_counts() == 2].head(10)
# Out:
# product_id
# B09F6S8BT6    2
# B09MQSCJQ1    2
# B0B2DJDCPX    2
# B094YFFSMY    2
# B09MT84WV5    2
# B078G6ZF5Z    2
# B07RD611Z8    2
# B07GVGTSLN    2
# B0B5LVS732    2
# B0B9BXKBC7    2
# Name: count, dtype: int64

# %%
# CHecking Only product id is same or other columns are also
df[df["product_id"]=="B09F6S8BT6"]
# Out:
#      product_id                                       product_name  \
# 22   B09F6S8BT6  Samsung 80 cm (32 Inches) Wondertainment Serie...
# 723  B09F6S8BT6  Samsung 80 cm (32 Inches) Wondertainment Serie...
#
#                                               category discounted_price  \
# 22   Electronics|HomeTheater,TV&Video|Televisions|S...          ₹13,490
# 723  Electronics|HomeTheater,TV&Video|Televisions|S...          ₹13,490
#
#     actual_price discount_percentage rating rating_count  \
# 22       ₹22,900                 41%    4.3       16,299
# 723      ₹22,900                 41%    4.3       16,299
#
#                                          about_product  \
# 22   Resolution: HD Ready (1366x768) | Refresh Rate...
# 723  Resolution: HD Ready (1366x768) | Refresh Rate...
#
#                                                user_id  \
# 22   AHEVO4Q5NM4YXMG2HDDXC5XMBGRQ,AFZPH7ZAWX5VDY3HO...
# 723  AHEVO4Q5NM4YXMG2HDDXC5XMBGRQ,AFZPH7ZAWX5VDY3HO...
#
# ...

# %%
df[df["product_id"].duplicated(keep=False)].sort_values("product_id").head(10)
# Out:
#       product_id                                       product_name  \
# 46    B002PD61Y4  D-Link DWA-131 300 Mbps Wireless Nano USB Adap...
# 881   B002PD61Y4  D-Link DWA-131 300 Mbps Wireless Nano USB Adap...
# 33    B008FWZGSG  Samsung Original Type C to C Cable - 3.28 Feet...
# 833   B008FWZGSG  Samsung Original Type C to C Cable - 3.28 Feet...
# 40    B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...
# 852   B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...
# 30    B00NH11PEY  AmazonBasics USB 2.0 - A-Male to A-Female Exte...
# 802   B00NH11PEY  AmazonBasics USB 2.0 - A-Male to A-Female Exte...
# 90    B0141EZMAI  Gizga Essentials USB WiFi Adapter for PC, 150 ...
# 1019  B0141EZMAI  Gizga Essentials USB WiFi Adapter for PC, 150 ...
#
#                                                category discounted_price  \
# 46    Computers&Accessories|NetworkingDevices|Networ...             ₹507
# ...

# %%
# Gives all duplicate Product id counts
df[df["product_id"].duplicated(keep=False)].shape
# Out:
# (206, 16)

# %%
df["product_id"].value_counts().value_counts().sort_index()
# Out:
# count
# 1    1259
# 2      69
# 3      22
# Name: count, dtype: int64

# %%
# How much Product id NAN
df["product_id"].isnull().sum()
# Out:
# np.int64(2)

# %%
# All rows that contain NAN Values
df[df.isnull().any(axis=1)]
# Out:
#       product_id                                       product_name  \
# 5     B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 6     B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 8     B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
# 9     B082LZGK39  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 12           NaN  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 20    B09C6HXFC1  Duracell USB Lightning Apple Certified (Mfi) B...
# 44    B09NJN8L25  FLiX (Beetel USB to Micro USB PVC Data Sync & ...
# 63    B01GGKZ0V6  AmazonBasics USB Type-C to USB Type-C 2.0 Cabl...
# 98    B00V4BGDKU  TP-Link UE300 USB 3.0 to RJ45 Gigabit Ethernet...
# 104          NaN                                                NaN
# 150   B0BB3CBFBM  VU 138 cm (55 inches) Premium Series 4K Ultra ...
# 156   B084N133Y7  Belkin Apple Certified Lightning To Type C Cab...
# 157   B088Z1YWBC  EGate i9 Pro-Max 1080p Native Full HD Projecto...
# ...

# %%
# All columns missing values count greater than Zero
missing = df.isnull().sum()
missing = missing[missing>0]
missing.sort_values(ascending=False)
# missing
# Out:
# product_link           9
# about_product          6
# review_title           6
# review_content         5
# img_link               5
# category               3
# user_id                3
# user_name              3
# product_id             2
# rating_count           2
# rating                 1
# discounted_price       1
# product_name           1
# discount_percentage    1
# actual_price           1
# review_id              1
# dtype: int64

# %%
# give row that NAN Value in column Rating 
df[df["rating"].isnull()]
# Out:
#     product_id                                       product_name  \
# 63  B01GGKZ0V6  AmazonBasics USB Type-C to USB Type-C 2.0 Cabl...
#
#                                              category discounted_price  \
# 63  Computers&Accessories|Accessories&Peripherals|...             ₹329
#
#    actual_price discount_percentage rating rating_count  \
# 63         ₹845                 61%    NaN       29,746
#
#                                         about_product  \
# 63  Connect Usb Type-C Enabled Devices (Macbook, C...
#
#                                               user_id  \
# 63  AEITVIFC7WZAEQDIVWPB4KUGKLRQ,AHQVFZCGAMMHEBBOY...
#
#                                             user_name  \
# 63  harpreet,Y Kiran Korneli Reddy,Kadir,SP,Mr Sab...
#
#                                             review_id  \
# 63  R37S13YALMRPGK,R2OU2YTGFEMJHE,R25SDG11W8EAU9,R...
#
#                                          review_title  \
# 63  Its ok product not too good not bad,Cheap and ...
#
# ...

# %%
# give row that NAN Value in column Discounted price 

df[df["discounted_price"].isnull()]
# Out:
#     product_id product_name category discounted_price actual_price  \
# 104        NaN          NaN      NaN              NaN         ₹999
#
#     discount_percentage rating rating_count  \
# 104                 65%    4.2       13,120
#
#                                          about_product  \
# 104  [High Compatibility] : iPhones, iPad Air, iPad...
#
#                                                user_id  \
# 104  AGKNFVSMZCSEFHPASWFBOIYKRZJA,AERBQW23ELEQZRWXW...
#
#                                              user_name  \
# 104  Pratik,Amazon Customer,Abhishek,Derrick Angels...
#
#                                              review_id  \
# 104  R3JCOBHM1JXUQ0,R24Q3GIRGESSP7,R3ST56H0XWNVV2,R...
#
#                                           review_title  \
# 104  Good product,Is worth the money you are paying...
#
#                                         review_content  \
# 104  I like the product and I used it for my iphone...
#
# ...

# %%
# give row that NAN Value in column Actual price 
df[df["actual_price"].isnull()]
# Out:
#    product_id                                       product_name category  \
# 12        NaN  AmazonBasics Flexible Premium HDMI Cable (Blac...      NaN
#
#    discounted_price actual_price discount_percentage rating rating_count  \
# 12             ₹219          NaN                 NaN    4.4     4,26,973
#
#                                         about_product user_id  \
# 12  Flexible, lightweight HDMI cable for connectin...     NaN
#
#                                             user_name  \
# 12  Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
#
#                                             review_id  \
# 12  R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
#
#                                          review_title  \
# 12  It's quite good and value for money,Works well...
#
#                                        review_content  \
# 12  I am using it for 14 days now. The experience ...
#
#                                              img_link  \
# ...

# %%
# give row that NAN Value in column Discounted Percentage 
df[df["discount_percentage"].isnull()]
# Out:
#    product_id                                       product_name category  \
# 12        NaN  AmazonBasics Flexible Premium HDMI Cable (Blac...      NaN
#
#    discounted_price actual_price discount_percentage rating rating_count  \
# 12             ₹219          NaN                 NaN    4.4     4,26,973
#
#                                         about_product user_id  \
# 12  Flexible, lightweight HDMI cable for connectin...     NaN
#
#                                             user_name  \
# 12  Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
#
#                                             review_id  \
# 12  R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
#
#                                          review_title  \
# 12  It's quite good and value for money,Works well...
#
#                                        review_content  \
# 12  I am using it for 14 days now. The experience ...
#
#                                              img_link  \
# ...

# %%
# give row that NAN Value in column Rating count
df[df["rating_count"].isnull()]
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 324  Computers&Accessories|Accessories&Peripherals|...             ₹249
#
#     actual_price discount_percentage rating rating_count  \
# 282         ₹999                 80%      3          NaN
# 324         ₹999                 75%      5          NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# 324  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
# ...

# %%
# give row that colums have rating count equals to 13120
df[df["rating_count"]== "13,120"]
# Out:
#      product_id                                       product_name  \
# 104         NaN                                                NaN
# 166  B07JPJJZ2H  Wayona Nylon Braided Lightning USB Data Sync &...
#
#                                               category discounted_price  \
# 104                                                NaN              NaN
# 166  Computers&Accessories|Accessories&Peripherals|...             ₹399
#
#     actual_price discount_percentage rating rating_count  \
# 104         ₹999                 65%    4.2       13,120
# 166       ₹1,299                 69%    4.2       13,120
#
#                                          about_product  \
# 104  [High Compatibility] : iPhones, iPad Air, iPad...
# 166  [High Compatibility] : iPhones, iPad Air, iPad...
#
#                                                user_id  \
# 104  AGKNFVSMZCSEFHPASWFBOIYKRZJA,AERBQW23ELEQZRWXW...
# 166  AGKNFVSMZCSEFHPASWFBOIYKRZJA,AERBQW23ELEQZRWXW...
#
# ...

# %%
# give row that colums have rating count equals to 426973
df[df["rating_count"]== "4,26,973"]
# Out:
#     product_id                                       product_name  \
# 12         NaN  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 47  B014I8SSD0  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...
# 65  B014I8SX4Y  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...
#
#                                              category discounted_price  \
# 12                                                NaN             ₹219
# 47  Electronics|HomeTheater,TV&Video|Accessories|C...             ₹309
# 65  Electronics|HomeTheater,TV&Video|Accessories|C...             ₹309
#
#    actual_price discount_percentage rating rating_count  \
# 12          NaN                 NaN    4.4     4,26,973
# 47         ₹475                 35%    4.4     4,26,973
# 65       ₹1,400                 78%    4.4     4,26,973
#
#                                         about_product  \
# 12  Flexible, lightweight HDMI cable for connectin...
# 47  Please select appropriate display resolution &...
# ...

# %%
# give row that  column product id contain product ids equals to  "B0B94JPY2N","B0BQRJ3C47"

df[df["product_id"].isin(["B0B94JPY2N","B0BQRJ3C47"])]
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 324  Computers&Accessories|Accessories&Peripherals|...             ₹249
#
#     actual_price discount_percentage rating rating_count  \
# 282         ₹999                 80%      3          NaN
# 324         ₹999                 75%      5          NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# 324  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
# ...

# %%
# Give Dtype of columns "discounted_price","actual_price","discount_percentage", "rating","rating_count"
df[["discounted_price","actual_price","discount_percentage",
    "rating","rating_count"]].dtypes
# Out:
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# dtype: object

# %%
df[["discounted_price","actual_price","discount_percentage",
    "rating","rating_count"]].head()
# Out:
#   discounted_price actual_price discount_percentage rating rating_count
# 0             ₹399       ₹1,099                 64%    4.2       24,269
# 1             ₹199         ₹349                 43%      4       43,994
# 2             ₹199       ₹1,899                 90%    3.9        7,928
# 3             ₹329         ₹699                 53%    4.2       94,363
# 4             ₹154         ₹399                 61%    4.2       16,905

# %%
df[["discounted_price","actual_price","discount_percentage",
    "rating","rating_count"]].tail()
# Out:
#      discounted_price actual_price discount_percentage rating rating_count
# 1460             ₹379         ₹919                 59%      4        1,090
# 1461           ₹2,280       ₹3,045                 25%    4.1        4,118
# 1462           ₹2,219       ₹3,080                 28%    3.6          468
# 1463           ₹1,399       ₹1,890                 26%      4        8,031
# 1464           ₹2,863       ₹3,690                 22%    4.3        6,987

# %%
# Convert Discounted Price data type object to Float
df["discounted_price"] = df["discounted_price"].str.replace("₹","",regex=False)
df["discounted_price"] = df["discounted_price"].str.replace(",","",regex=False)
df["discounted_price"] = pd.to_numeric(df["discounted_price"])
df["discounted_price"].head()
# Out:
# 0    399.0
# 1    199.0
# 2    199.0
# 3    329.0
# 4    154.0
# Name: discounted_price, dtype: float64

# %%
# Convert Actula Price data type object to Float

df["actual_price"] = df["actual_price"].str.replace("₹","",regex=False)
df["actual_price"] = df["actual_price"].str.replace(",","",regex=False)
df["actual_price"] = pd.to_numeric(df["actual_price"])
df["actual_price"].head()
# Out:
# 0    1099.0
# 1     349.0
# 2    1899.0
# 3     699.0
# 4     399.0
# Name: actual_price, dtype: float64

# %%
# Convert Discounted percentage data type object to Float
df["discount_percentage"] = df["discount_percentage"].str.replace("%","",regex=False)
df["discount_percentage"] = pd.to_numeric(df["discount_percentage"])
df["discount_percentage"].head()
# Out:
# 0    64.0
# 1    43.0
# 2    90.0
# 3    53.0
# 4    61.0
# Name: discount_percentage, dtype: float64

# %%
# Convert Rating data type object to Float

df["rating"] = df["rating"].str.replace("|","",regex=False)
df["rating"] = pd.to_numeric(df["rating"])
df["rating"].head()
# Out:
# 0    4.2
# 1    4.0
# 2    3.9
# 3    4.2
# 4    4.2
# Name: rating, dtype: float64

# %%
# Convert Rating count data type object to Float

df["rating_count"] = df["rating_count"].str.replace(",","",regex=False)
df["rating_count"] = pd.to_numeric(df["rating_count"])
df["rating_count"].head()
# Out:
# 0    24269.0
# 1    43994.0
# 2     7928.0
# 3    94363.0
# 4    16905.0
# Name: rating_count, dtype: float64

# %%
# Give Dtype of columns "discounted_price","actual_price","discount_percentage","rating","rating_count"
df[["discounted_price","actual_price","discount_percentage",
    "rating","rating_count"]].dtypes
# Out:
# discounted_price       float64
# actual_price           float64
# discount_percentage    float64
# rating                 float64
# rating_count           float64
# dtype: object

# %%
# how munch NAN Value columns "discounted_price","actual_price","discount_percentage","rating","rating_count" contain
df[["discounted_price","actual_price","discount_percentage",
    "rating","rating_count"]].isnull().sum()
# Out:
# discounted_price       1
# actual_price           1
# discount_percentage    1
# rating                 2
# rating_count           2
# dtype: int64

# %%
df[["discounted_price","actual_price","discount_percentage",
    "rating","rating_count"]].describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1464.000000    1464.000000          1464.000000  1463.000000
# mean        3127.207261    5448.231749            47.676913     4.096514
# std         6946.297815   10877.835006            21.636122     0.291761
# min           39.000000      39.000000             0.000000     2.000000
# 25%          323.750000     800.000000            32.000000     4.000000
# 50%          799.000000    1670.000000            50.000000     4.100000
# 75%         1999.000000    4303.750000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %%
# Finding invalid discounts is any discounts price exist more than actual price.
df[df["discounted_price"] > df["actual_price"]]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, discounted_price, actual_price, discount_percentage, rating, rating_count, about_product, user_id, user_name, review_id, review_title, review_content, img_link, product_link]
# Index: []

# %%
# Finding Invalid discounts 
df[(df["discount_percentage"] < 0) | (df["discount_percentage"] > 100)]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, discounted_price, actual_price, discount_percentage, rating, rating_count, about_product, user_id, user_name, review_id, review_title, review_content, img_link, product_link]
# Index: []

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# product_link           9
# about_product          6
# review_title           6
# review_content         5
# img_link               5
# category               3
# user_id                3
# user_name              3
# rating_count           2
# rating                 2
# product_id             2
# discounted_price       1
# actual_price           1
# discount_percentage    1
# product_name           1
# review_id              1
# dtype: int64

# %%
#Finding rows that doesnot have product id
df[df["product_id"].isnull()]
# Out:
#     product_id                                       product_name category  \
# 12         NaN  AmazonBasics Flexible Premium HDMI Cable (Blac...      NaN
# 104        NaN                                                NaN      NaN
#
#      discounted_price  actual_price  discount_percentage  rating  \
# 12              219.0           NaN                  NaN     4.4
# 104               NaN         999.0                 65.0     4.2
#
#      rating_count                                      about_product  \
# 12       426973.0  Flexible, lightweight HDMI cable for connectin...
# 104       13120.0  [High Compatibility] : iPhones, iPad Air, iPad...
#
#                                                user_id  \
# 12                                                 NaN
# 104  AGKNFVSMZCSEFHPASWFBOIYKRZJA,AERBQW23ELEQZRWXW...
#
#                                              user_name  \
# 12   Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# ...

# %%
# Comapre two rows where that same rating count 
df[df["rating_count"] == 13120][["product_id","product_name","category","discounted_price","actual_price","discount_percentage","rating_count"]]
# Out:
#      product_id                                       product_name  \
# 104         NaN                                                NaN
# 166  B07JPJJZ2H  Wayona Nylon Braided Lightning USB Data Sync &...
#
#                                               category  discounted_price  \
# 104                                                NaN               NaN
# 166  Computers&Accessories|Accessories&Peripherals|...             399.0
#
#      actual_price  discount_percentage  rating_count
# 104         999.0                 65.0       13120.0
# 166        1299.0                 69.0       13120.0

# %%
# Now assign the product id , name and category of row 166 in row 104.
df.loc[104, "product_id"] = df.loc[166, "product_id"]
df.loc[104, "product_name"] = df.loc[166, "product_name"]
df.loc[104, "category"] = df.loc[166, "category"]
df.loc[104, ["product_id","product_name","category","discounted_price","actual_price","discount_percentage"]]
# Out:
# product_id                                                    B07JPJJZ2H
# product_name           Wayona Nylon Braided Lightning USB Data Sync &...
# category               Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                     NaN
# actual_price                                                       999.0
# discount_percentage                                                 65.0
# Name: 104, dtype: object

# %%
# checking the number of null cell in each columns 
df.isnull().sum().sort_values(ascending=False)
# Out:
# product_link           9
# about_product          6
# review_title           6
# review_content         5
# img_link               5
# user_id                3
# user_name              3
# category               2
# rating_count           2
# rating                 2
# product_id             1
# discount_percentage    1
# discounted_price       1
# actual_price           1
# review_id              1
# product_name           0
# dtype: int64

# %%
# It give rows that have null discountes price , actual price and discount percentage.
df[df["discounted_price"].isnull() | df["actual_price"].isnull() | df["discount_percentage"].isnull()]
# Out:
#      product_id                                       product_name  \
# 12          NaN  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 104  B07JPJJZ2H  Wayona Nylon Braided Lightning USB Data Sync &...
#
#                                               category  discounted_price  \
# 12                                                 NaN             219.0
# 104  Computers&Accessories|Accessories&Peripherals|...               NaN
#
#      actual_price  discount_percentage  rating  rating_count  \
# 12            NaN                  NaN     4.4      426973.0
# 104         999.0                 65.0     4.2       13120.0
#
#                                          about_product  \
# 12   Flexible, lightweight HDMI cable for connectin...
# 104  [High Compatibility] : iPhones, iPad Air, iPad...
#
#                                                user_id  \
# 12                                                 NaN
# 104  AGKNFVSMZCSEFHPASWFBOIYKRZJA,AERBQW23ELEQZRWXW...
#
# ...

# %%
df.isnull().sum()
# Out:
# product_id             1
# product_name           0
# category               2
# discounted_price       1
# actual_price           1
# discount_percentage    1
# rating                 2
# rating_count           2
# about_product          6
# user_id                3
# user_name              3
# review_id              1
# review_title           6
# review_content         5
# img_link               5
# product_link           9
# dtype: int64

# %%
# give rows where rating or rating count has null cell
df[df["rating"].isnull() | df["rating_count"].isnull()]
# Out:
#       product_id                                       product_name  \
# 63    B01GGKZ0V6  AmazonBasics USB Type-C to USB Type-C 2.0 Cabl...
# 282   B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324   B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 63    Computers&Accessories|Accessories&Peripherals|...             329.0
# 282   Computers&Accessories|Accessories&Peripherals|...             199.0
# 324   Computers&Accessories|Accessories&Peripherals|...             249.0
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage  rating  rating_count  \
# 63           845.0                 61.0     NaN       29746.0
# 282          999.0                 80.0     3.0           NaN
# 324          999.0                 75.0     5.0           NaN
# ...

# %%
# give row where category has null cell
df[df["category"].isnull()]
# Out:
#     product_id                                       product_name category  \
# 12         NaN  AmazonBasics Flexible Premium HDMI Cable (Blac...      NaN
# 20  B09C6HXFC1  Duracell USB Lightning Apple Certified (Mfi) B...      NaN
#
#     discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 12             219.0           NaN                  NaN     4.4      426973.0
# 20             970.0        1799.0                 46.0     4.5         815.0
#
#                                         about_product  \
# 12  Flexible, lightweight HDMI cable for connectin...
# 20  Supports Ios Devices With Max Output Up To 2.4...
#
#                                               user_id  \
# 12                                                NaN
# 20  AFNYIBWKJLJQKY4BGK77ZOTVMORA,AFCTNNMP2LZLY5466...
#
#                                             user_name  \
# 12  Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 20                                                NaN
#
# ...

# %%
# Now we are finding product IDs with the id "B09C6HXFC1" 
# And check which row is matching with our null category cell
df[df["product_id"]=="B09C6HXFC1"]
# Out:
#      product_id                                       product_name  \
# 20   B09C6HXFC1  Duracell USB Lightning Apple Certified (Mfi) B...
# 467  B09C6HXFC1  Duracell USB Lightning Apple Certified (Mfi) B...
# 700  B09C6HXFC1  Duracell USB Lightning Apple Certified (Mfi) B...
#
#                                               category  discounted_price  \
# 20                                                 NaN             970.0
# 467  Computers&Accessories|Accessories&Peripherals|...             970.0
# 700  Computers&Accessories|Accessories&Peripherals|...             970.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 20         1799.0                 46.0     4.5         815.0
# 467        1799.0                 46.0     4.5         815.0
# 700        1799.0                 46.0     4.5         815.0
#
#                                          about_product  \
# 20   Supports Ios Devices With Max Output Up To 2.4...
# ...

# %%
# Our row number 467 is matching with row 20 so we assign row 467 category to row 20
df.loc[20,"category"] = df.loc[467,"category"]
df[df["product_id"]=="B09C6HXFC1"]
# Out:
#      product_id                                       product_name  \
# 20   B09C6HXFC1  Duracell USB Lightning Apple Certified (Mfi) B...
# 467  B09C6HXFC1  Duracell USB Lightning Apple Certified (Mfi) B...
# 700  B09C6HXFC1  Duracell USB Lightning Apple Certified (Mfi) B...
#
#                                               category  discounted_price  \
# 20   Computers&Accessories|Accessories&Peripherals|...             970.0
# 467  Computers&Accessories|Accessories&Peripherals|...             970.0
# 700  Computers&Accessories|Accessories&Peripherals|...             970.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 20         1799.0                 46.0     4.5         815.0
# 467        1799.0                 46.0     4.5         815.0
# 700        1799.0                 46.0     4.5         815.0
#
#                                          about_product  \
# 20   Supports Ios Devices With Max Output Up To 2.4...
# ...

# %%
# now we again check our category columns is any null cell exist
df[df["category"].isnull()] 
# Still we have row 12 with 1 null cell category column
# Out:
#    product_id                                       product_name category  \
# 12        NaN  AmazonBasics Flexible Premium HDMI Cable (Blac...      NaN
#
#     discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 12             219.0           NaN                  NaN     4.4      426973.0
#
#                                         about_product user_id  \
# 12  Flexible, lightweight HDMI cable for connectin...     NaN
#
#                                             user_name  \
# 12  Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
#
#                                             review_id  \
# 12  R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
#
#                                          review_title  \
# 12  It's quite good and value for money,Works well...
#
#                                        review_content  \
# 12  I am using it for 14 days now. The experience ...
#
#                                              img_link  \
# ...

# %%
# now we are checking rows that match with row 12 and column Rating count aontain 426973
df[(df["discounted_price"] == 219) | (df["rating_count"] == 426973)]
# Out:
#       product_id                                       product_name  \
# 12           NaN  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 47    B014I8SSD0  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...
# 65    B014I8SX4Y  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...
# 69    B01GGKYKQM  Amazon Basics USB Type-C to USB-A 2.0 Male Fas...
# 562   B01GGKYKQM  Amazon Basics USB Type-C to USB-A 2.0 Male Fas...
# 575   B09VGKFM7Y  Amazon Basics 2 Amp USB Wall Charger & Micro U...
# 684   B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 974   B01GGKYKQM  Amazon Basics USB Type-C to USB-A 2.0 Male Fas...
# 1435  B089BDBDGM  Kuber Industries Waterproof Round Laundry Bag/...
#
#                                                category  discounted_price  \
# 12                                                  NaN             219.0
# 47    Electronics|HomeTheater,TV&Video|Accessories|C...             309.0
# ...

# %%
# Comapring Row 12 and 684
df.loc[[12, 684], ["product_name","about_product","review_id","review_title","review_content","img_link","product_link","category"]]
# Out:
#                                           product_name  \
# 12   AmazonBasics Flexible Premium HDMI Cable (Blac...
# 684  AmazonBasics Flexible Premium HDMI Cable (Blac...
#
#                                          about_product  \
# 12   Flexible, lightweight HDMI cable for connectin...
# 684  Flexible, lightweight HDMI cable for connectin...
#
#                                              review_id  \
# 12   R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 684  R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
#
#                                           review_title  \
# 12   It's quite good and value for money,Works well...
# 684  It's quite good and value for money,Works well...
#
#                                         review_content  \
# 12   I am using it for 14 days now. The experience ...
# 684  I am using it for 14 days now. The experience ...
#
#                                               img_link  \
# 12   https://m.media-amazon.com/images/I/41nPYaWA+M...
# ...

# %%
# Assigning catgory of row 684 to 12 
df.loc[12,"category"] = df.loc[684,"category"]
df.loc[12,"category"]
# Out:
# 'Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables'

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# product_link           9
# about_product          6
# review_title           6
# review_content         5
# img_link               5
# user_id                3
# user_name              3
# rating                 2
# rating_count           2
# product_id             1
# discounted_price       1
# discount_percentage    1
# actual_price           1
# review_id              1
# product_name           0
# category               0
# dtype: int64

# %%
# Column that have product is null
df[df["product_id"].isnull()]
# Out:
#    product_id                                       product_name  \
# 12        NaN  AmazonBasics Flexible Premium HDMI Cable (Blac...
#
#                                              category  discounted_price  \
# 12  Electronics|HomeTheater,TV&Video|Accessories|C...             219.0
#
#     actual_price  discount_percentage  rating  rating_count  \
# 12           NaN                  NaN     4.4      426973.0
#
#                                         about_product user_id  \
# 12  Flexible, lightweight HDMI cable for connectin...     NaN
#
#                                             user_name  \
# 12  Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
#
#                                             review_id  \
# 12  R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
#
#                                          review_title  \
# 12  It's quite good and value for money,Works well...
#
#                                        review_content  \
# ...

# %%
df.loc[[684,12],["product_id","product_name","product_link"]]
# Out:
#      product_id                                       product_name  \
# 684  B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 12          NaN  AmazonBasics Flexible Premium HDMI Cable (Blac...
#
#                                           product_link
# 684  https://www.amazon.in/AmazonBasics-Flexible-HD...
# 12   https://www.amazon.in/AmazonBasics-Flexible-HD...

# %%
# Assigning product id of row 684 to row 12
df.loc[12,"product_id"] = df.loc[684, "product_id"]
df.loc[12]
# Out:
# product_id                                                    B07KSMBL2H
# product_name           AmazonBasics Flexible Premium HDMI Cable (Blac...
# category               Electronics|HomeTheater,TV&Video|Accessories|C...
# discounted_price                                                   219.0
# actual_price                                                         NaN
# discount_percentage                                                  NaN
# rating                                                               4.4
# rating_count                                                    426973.0
# about_product          Flexible, lightweight HDMI cable for connectin...
# user_id                                                              NaN
# user_name              Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# review_id              R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# review_title           It's quite good and value for money,Works well...
# ...

# %%
df[df["review_id"].isnull()]
# Out:
#     product_id                                       product_name  \
# 44  B09NJN8L25  FLiX (Beetel USB to Micro USB PVC Data Sync & ...
#
#                                              category  discounted_price  \
# 44  Computers&Accessories|Accessories&Peripherals|...              59.0
#
#     actual_price  discount_percentage  rating  rating_count  \
# 44         199.0                 70.0     4.0        9378.0
#
#                                         about_product  \
# 44  Micro USB charging cable for android phones an...
#
#                                               user_id  \
# 44  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
#
#                                             user_name review_id  \
# 44  $@|\|TO$|-|,Sethu madhav,Akash Thakur,Burger P...       NaN
#
#                                          review_title  \
# 44  Worked on iPhone 7 and didn’t work on XR,Good ...
#
#                                        review_content  \
# ...

# %%
df[df["product_id"] == "B09NJN8L25"][["product_id","product_name","review_id"]]
# Out:
#     product_id                                       product_name review_id
# 44  B09NJN8L25  FLiX (Beetel USB to Micro USB PVC Data Sync & ...       NaN

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       1
# actual_price           1
# discount_percentage    1
# rating                 2
# rating_count           2
# about_product          6
# user_id                3
# user_name              3
# review_id              1
# review_title           6
# review_content         5
# img_link               5
# product_link           9
# dtype: int64

# %%
# Give row where discount price is null
df[df["discounted_price"].isnull()][["product_id","product_name","discounted_price","actual_price","discount_percentage","rating","rating_count"]]
# Out:
#      product_id                                       product_name  \
# 104  B07JPJJZ2H  Wayona Nylon Braided Lightning USB Data Sync &...
#
#      discounted_price  actual_price  discount_percentage  rating  rating_count
# 104               NaN         999.0                 65.0     4.2       13120.0

# %%
# Give row where actual price is null

df[df["actual_price"].isnull()][["product_id","product_name","discounted_price","actual_price","discount_percentage","rating","rating_count"]]
# Out:
#     product_id                                       product_name  \
# 12  B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
#
#     discounted_price  actual_price  discount_percentage  rating  rating_count
# 12             219.0           NaN                  NaN     4.4      426973.0

# %%
# Give row where product id equals to "B07KSMBL2H"

df[df["product_id"] == "B07KSMBL2H"][["product_id","product_name","discounted_price","actual_price","discount_percentage","rating","rating_count"]]
# Out:
#      product_id                                       product_name  \
# 12   B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 684  B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
#
#      discounted_price  actual_price  discount_percentage  rating  rating_count
# 12              219.0           NaN                  NaN     4.4      426973.0
# 684             219.0         700.0                 69.0     4.4      426972.0

# %%
# Assigning Actual price and Discounted price of row 684 to row 12 
df.loc[12,"actual_price"] = df.loc[684,"actual_price"]
df.loc[12,"discount_percentage"] = df.loc[684,"discount_percentage"]
df.loc[12,["product_id","product_name","discounted_price","actual_price","discount_percentage","rating","rating_count"]]
# Out:
# product_id                                                    B07KSMBL2H
# product_name           AmazonBasics Flexible Premium HDMI Cable (Blac...
# discounted_price                                                   219.0
# actual_price                                                       700.0
# discount_percentage                                                 69.0
# rating                                                               4.4
# rating_count                                                    426973.0
# Name: 12, dtype: object

# %%
# Give row where Rating is null
df[df["rating"].isnull()][["product_id","product_name","discounted_price","actual_price","discount_percentage","rating","rating_count"]]
# Out:
#       product_id                                       product_name  \
# 63    B01GGKZ0V6  AmazonBasics USB Type-C to USB Type-C 2.0 Cabl...
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#       discounted_price  actual_price  discount_percentage  rating  \
# 63               329.0         845.0                 61.0     NaN
# 1279            2099.0        2499.0                 16.0     NaN
#
#       rating_count
# 63         29746.0
# 1279         992.0

# %%
# Give Row where product id equals to "B01GGKZ0V6"
df[df["product_id"] == "B01GGKZ0V6"][["product_id","product_name","discounted_price","actual_price","discount_percentage","rating","rating_count"]]
# Out:
#      product_id                                       product_name  \
# 63   B01GGKZ0V6  AmazonBasics USB Type-C to USB Type-C 2.0 Cabl...
# 943  B01GGKZ0V6  AmazonBasics USB Type-C to USB Type-C 2.0 Cabl...
#
#      discounted_price  actual_price  discount_percentage  rating  rating_count
# 63              329.0         845.0                 61.0     NaN       29746.0
# 943             329.0         845.0                 61.0     4.2       29746.0

# %%
# Assigning Rating of row 943 to row 63
df.loc[63,"rating"] = df.loc[943,"rating"]

df.loc[63,["product_id","product_name","discounted_price","actual_price","discount_percentage","rating","rating_count"]]
# Out:
# product_id                                                    B01GGKZ0V6
# product_name           AmazonBasics USB Type-C to USB Type-C 2.0 Cabl...
# discounted_price                                                   329.0
# actual_price                                                       845.0
# discount_percentage                                                 61.0
# rating                                                               4.2
# rating_count                                                     29746.0
# Name: 63, dtype: object

# %%
# Give Row where product id equals to "B08L12N5H1"
df[df["product_id"] == "B08L12N5H1"][["product_id","product_name","discounted_price","actual_price","discount_percentage","rating","rating_count"]]
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#       discounted_price  actual_price  discount_percentage  rating  \
# 1279            2099.0        2499.0                 16.0     NaN
#
#       rating_count
# 1279         992.0

# %%
df[["discounted_price","actual_price","discount_percentage","rating","rating_count"]].isnull().sum()
# Out:
# discounted_price       1
# actual_price           0
# discount_percentage    0
# rating                 1
# rating_count           2
# dtype: int64

# %%
# Give Row where Rating count is null
df[df["rating_count"].isnull()][["product_id","product_name","discounted_price","actual_price","discount_percentage","rating","rating_count"]]
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#      discounted_price  actual_price  discount_percentage  rating  rating_count
# 282             199.0         999.0                 80.0     3.0           NaN
# 324             249.0         999.0                 75.0     5.0           NaN

# %%
# Give Row where product id equals to "B0B94JPY2N"
df[df["product_id"] == "B0B94JPY2N"][["product_id","product_name","discounted_price","actual_price","discount_percentage","rating","rating_count"]]
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
#
#      discounted_price  actual_price  discount_percentage  rating  rating_count
# 282             199.0         999.0                 80.0     3.0           NaN

# %%
# Give Row where product id equals to "B0BQRJ3C47"
df[df["product_id"] == "B0BQRJ3C47"][["product_id","product_name","discounted_price","actual_price","discount_percentage","rating","rating_count"]]
# Out:
#      product_id                                       product_name  \
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#      discounted_price  actual_price  discount_percentage  rating  rating_count
# 324             249.0         999.0                 75.0     5.0           NaN

# %%
# Giev row where Discounted price is null
df[df["discounted_price"].isnull()][["product_id","product_name","discounted_price","actual_price","discount_percentage","rating","rating_count"]]
# Out:
#      product_id                                       product_name  \
# 104  B07JPJJZ2H  Wayona Nylon Braided Lightning USB Data Sync &...
#
#      discounted_price  actual_price  discount_percentage  rating  rating_count
# 104               NaN         999.0                 65.0     4.2       13120.0

# %%
df["category"].isnull().sum()
# Out:
# np.int64(0)

# %%
# Give counts of unique category count
df["category"].nunique()
# Out:
# 211

# %%
# Give How many times each catagory repeat
df["category"].value_counts().head(20)
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                        233
# Electronics|WearableTechnology|SmartWatches                                                               76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                      68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                             63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                              52
# Electronics|HomeTheater,TV&Video|Accessories|RemoteControls                                               49
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|MixerGrinders                                  27
# Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Mice                            24
# ...

# %%
(df["category"] != df["category"].str.strip()).sum()
# Out:
# np.int64(0)

# %%
df["category"].str.lower().nunique()
# Out:
# 211

# %%
df[["review_title","review_content"]].isnull().sum()
# Out:
# review_title      6
# review_content    5
# dtype: int64

# %%
df[["user_id","user_name"]].isnull().sum()
# Out:
# user_id      3
# user_name    3
# dtype: int64

# %%
df[df["user_id"].isnull() | df["user_name"].isnull()][["product_id","user_id","user_name"]]
# Out:
#      product_id                                            user_id  \
# 6    B08WRWPM22                                                NaN
# 12   B07KSMBL2H                                                NaN
# 20   B09C6HXFC1  AFNYIBWKJLJQKY4BGK77ZOTVMORA,AFCTNNMP2LZLY5466...
# 820  B01J1CFO5I                                                NaN
#
#                                              user_name
# 6                                                  NaN
# 12   Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 20                                                 NaN
# 820                                                NaN

# %%
df["product_id"].str.strip().eq("").sum()
# Out:
# np.int64(0)

# %%
df["product_id"].duplicated().sum()
# Out:
# np.int64(115)

# %%
df["product_id"].value_counts().value_counts()
# Out:
# count
# 1    1257
# 2      71
# 3      22
# Name: count, dtype: int64

# %%
df["product_name"].isnull().sum()
# Out:
# np.int64(0)

# %%
(df["product_id"].str.strip() == "").sum()
# Out:
# np.int64(0)

# %%
df["review_id"].isnull().sum()
# Out:
# np.int64(1)

# %%
df["review_id"].duplicated().sum()
# Out:
# np.int64(270)

# %%
df[["review_title","review_content"]].isnull().sum()
# Out:
# review_title      6
# review_content    5
# dtype: int64

# %%
(df["review_title"].fillna("").str.strip() == "").sum()
# Out:
# np.int64(6)

# %%
(df["review_content"].fillna("").str.strip() == "").sum()
# Out:
# np.int64(5)

# %%
df[["img_link", "product_link"]].isnull().sum()
# Out:
# img_link        5
# product_link    9
# dtype: int64

# %% [markdown]
# # Starting Of EDA Analysis

# %%
# Copy df data in analysis DataFrame
analysis_df = df[
    [
        "product_id",
        "product_name",
        "category",
        "discounted_price",
        "actual_price",
        "discount_percentage",
        "rating",
        "rating_count"
    ]
].copy()

# %%
analysis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1464 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
# dtypes: float64(5), object(3)
# memory usage: 91.7+ KB

# %%
# It give numerical columns numerical Analysis
analysis_df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1464.000000    1465.000000          1465.000000  1464.000000
# mean        3127.207261    5444.990635            47.691468     4.096585
# std         6946.297815   10874.826864            21.635905     0.291674
# min           39.000000      39.000000             0.000000     2.000000
# 25%          323.750000     800.000000            32.000000     4.000000
# 50%          799.000000    1650.000000            50.000000     4.100000
# 75%         1999.000000    4295.000000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %%
# Checking first 10 rows of highest discountes price
analysis_df["discounted_price"].sort_values(ascending=False).head(10)
# Out:
# 249     77990.0
# 325     61999.0
# 255     54990.0
# 192     47990.0
# 283     47990.0
# 332     46999.0
# 276     45999.0
# 533     44999.0
# 216     42999.0
# 1354    42990.0
# Name: discounted_price, dtype: float64

# %%
# Checking first 10 rows of lowest discounted price
analysis_df["discounted_price"].sort_values(ascending=True).head(10)
# Out:
# 975    39.00
# 997    39.00
# 645    39.00
# 616    50.00
# 178    57.89
# 710    59.00
# 44     59.00
# 727    59.00
# 478    59.00
# 23     59.00
# Name: discounted_price, dtype: float64

# %%
# Making Discounted price Histogram chart 
analysis_df["discounted_price"].plot(kind="hist", bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Now Checking Skewness of discounted price
analysis_df["discounted_price"].skew()
# Out:
# np.float64(4.45083094850029)

# %%
# Describing the numerical values of rating
analysis_df["rating"].describe()
# Out:
# count    1464.000000
# mean        4.096585
# std         0.291674
# min         2.000000
# 25%         4.000000
# 50%         4.100000
# 75%         4.300000
# max         5.000000
# Name: rating, dtype: float64

# %%
# Making histogram chart of Rating
analysis_df["rating"].plot(kind="hist",bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Checking Skewness of rating
analysis_df["rating"].skew()
# Out:
# np.float64(-1.2428954369559149)

# %%
# Now Checking skewness of Rating count
analysis_df["rating_count"].skew()
# Out:
# np.float64(5.673784182331723)

# %%
# Meking histogram chart of Rating count
analysis_df["rating_count"].plot(kind="hist",bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
analysis_df["discount_percentage"].describe()
# Out:
# count    1465.000000
# mean       47.691468
# std        21.635905
# min         0.000000
# 25%        32.000000
# 50%        50.000000
# 75%        63.000000
# max        94.000000
# Name: discount_percentage, dtype: float64

# %%
# calculating Q1, Q3 and IQR (Interquartile Range) for How middle is Spreed
Q1 = analysis_df["discount_percentage"].quantile(0.25)
Q3 = analysis_df["discount_percentage"].quantile(0.75)

IQR = Q3 - Q1

print("Q1 : ",Q1)
print("Q3 : ",Q3)
print("IQR : ",IQR)
# Out:
# Q1 :  32.0
# Q3 :  63.0
# IQR :  31.0

# %%
# It check Unvalid values of discounted price and give outliers
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = analysis_df[
    (analysis_df["discount_percentage"] < lower) |
    (analysis_df["discount_percentage"] > upper)
    ]
print("Lower Bound : ",lower)
print("Upper Bound : ",upper)
print("Number of Outliears : ",len(outliers))
# Out:
# Lower Bound :  -14.5
# Upper Bound :  109.5
# Number of Outliears :  0

# %%
analysis_df["category"].value_counts().head()
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables    233
# Electronics|WearableTechnology|SmartWatches                                           76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                  68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                         63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                          52
# Name: count, dtype: int64

# %%
# makeing a new column main category it split category by remove "|" and take index 0 and put it in the main category column 
analysis_df["main_category"] = analysis_df["category"].str.split("|").str[0]
analysis_df["main_category"].value_counts()
# Out:
# main_category
# Electronics              526
# Computers&Accessories    453
# Home&Kitchen             448
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: count, dtype: int64

# %%
# grouping main category and discounted price by discounted price average 
analysis_df.groupby("main_category")["discounted_price"].mean().sort_values(ascending=False)
# Out:
# main_category
# Electronics              5965.887833
# Car&Motorbike            2339.000000
# Home&Kitchen             2330.615647
# Health&PersonalCare       899.000000
# Computers&Accessories     843.742522
# MusicalInstruments        638.000000
# HomeImprovement           337.000000
# OfficeProducts            301.580645
# Toys&Games                150.000000
# Name: discounted_price, dtype: float64

# %%
# Counts how much a category come in the Main category column
analysis_df["main_category"].value_counts()
# Out:
# main_category
# Electronics              526
# Computers&Accessories    453
# Home&Kitchen             448
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: count, dtype: int64

# %%
# Grouping Main category , product_id and Discount price  
analysis_df.groupby("main_category").agg(
    product_count = ("product_id","count"),
    avg_discounted_price = ("discounted_price","mean")
)
# Out:
#                        product_count  avg_discounted_price
# main_category
# Car&Motorbike                      1           2339.000000
# Computers&Accessories            453            843.742522
# Electronics                      526           5965.887833
# Health&PersonalCare                1            899.000000
# Home&Kitchen                     448           2330.615647
# HomeImprovement                    2            337.000000
# MusicalInstruments                 2            638.000000
# OfficeProducts                    31            301.580645
# Toys&Games                         1            150.000000

# %%
# Calculating Average(mean) of discount percentage by grouping Main category
analysis_df.groupby("main_category")["discount_percentage"].mean().sort_values(ascending=False)
# Out:
# main_category
# HomeImprovement          57.500000
# Computers&Accessories    54.024283
# Health&PersonalCare      53.000000
# Electronics              50.828897
# MusicalInstruments       46.000000
# Car&Motorbike            42.000000
# Home&Kitchen             40.120536
# OfficeProducts           12.354839
# Toys&Games                0.000000
# Name: discount_percentage, dtype: float64

# %%
# Grouping Main category by calculating product count, average price, Average dicount and Average rating
category_summary = analysis_df.groupby("main_category").agg(
    product_count = ("product_id","count"),
    avg_price = ("discounted_price","mean"),
    avg_discount = ("discount_percentage","mean"),
    avg_rating = ("rating","mean")
)
category_summary.sort_values("product_count",ascending=False)
category_summary.sort_values("avg_rating",ascending=False)
# Out:
#                        product_count    avg_price  avg_discount  avg_rating
# main_category
# OfficeProducts                    31   301.580645     12.354839    4.309677
# Toys&Games                         1   150.000000      0.000000    4.300000
# HomeImprovement                    2   337.000000     57.500000    4.250000
# Computers&Accessories            453   843.742522     54.024283    4.154967
# Electronics                      526  5965.887833     50.828897    4.081749
# Home&Kitchen                     448  2330.615647     40.120536    4.040716
# Health&PersonalCare                1   899.000000     53.000000    4.000000
# MusicalInstruments                 2   638.000000     46.000000    3.900000
# Car&Motorbike                      1  2339.000000     42.000000    3.800000

# %%
# Give corelation between discount percentage and rating
analysis_df[["discount_percentage","rating"]].corr()
# Out:
#                      discount_percentage    rating
# discount_percentage             1.000000 -0.155375
# rating                         -0.155375  1.000000

# %%
# Give corelation between discount price and rating
analysis_df[["discounted_price","rating"]].corr()
# Out:
#                   discounted_price    rating
# discounted_price          1.000000  0.120446
# rating                    0.120446  1.000000

# %%
# Making Scatter plot of Discount price 
analysis_df.plot(
    x="discounted_price",
    y="rating",
    kind="scatter"
)
# Out:
# <Axes: xlabel='discounted_price', ylabel='rating'>

# %%
# Give corelation between rating and rating count 
analysis_df[["rating","rating_count"]].corr()
# Out:
#                 rating  rating_count
# rating        1.000000      0.102235
# rating_count  0.102235      1.000000

# %%
# Give corelation between discounted price and percentage
analysis_df[["discount_percentage","discounted_price"]].corr()
# Out:
#                      discount_percentage  discounted_price
# discount_percentage              1.00000          -0.24226
# discounted_price                -0.24226           1.00000

# %%
analysis_df["amount_saved"] = (analysis_df["actual_price"] - analysis_df["discounted_price"])

# %%
analysis_df["amount_saved"].describe()
# Out:
# count     1464.000000
# mean      2320.820253
# std       4605.840162
# min          0.000000
# 25%        370.750000
# 50%        800.000000
# 75%       1955.000000
# max      61910.000000
# Name: amount_saved, dtype: float64

# %%
analysis_df[["product_name","actual_price","discounted_price","amount_saved"]].sort_values("amount_saved",ascending=False).head(10)
# Out:
#                                            product_name  actual_price  \
# 249   Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...      139900.0
# 1182  Coway Professional Air Purifier for Home, Long...       59900.0
# 568   Samsung Galaxy S20 FE 5G (Cloud Navy, 8GB RAM,...       74999.0
# 150   VU 138 cm (55 inches) Premium Series 4K Ultra ...       65000.0
# 1354  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...       75990.0
# 283   LG 139 cm (55 inches) 4K Ultra HD Smart LED TV...       79990.0
# 1306  ECOVACS DEEBOT N8 2-in-1 Robotic Vacuum Cleane...       59900.0
# 255   VU 164 cm (65 inches) The GloLED Series 4K Sma...       85000.0
# 108   VU 139 cm (55 inches) The GloLED Series 4K Sma...       65000.0
# 323   TCL 108 cm (43 inches) 4K Ultra HD Certified A...       51990.0
#
#       discounted_price  amount_saved
# 249            77990.0       61910.0
# 1182           14400.0       45500.0
# 568            37990.0       37009.0
# 150            29990.0       35010.0
# ...

# %%
analysis_df[["product_name","actual_price","discounted_price","discount_percentage"]].sort_values("discount_percentage",ascending=False).head(10)
# Out:
#                                           product_name  actual_price  \
# 695  rts [2 Pack] Mini USB C Type C Adapter Plug, T...        4999.0
# 372  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...       19999.0
# 380  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...       19999.0
# 364  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...       19999.0
# 368  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...       19999.0
# 334  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...       19999.0
# 557  LAPSTER 12pcs Spiral Cable Protectors for Char...         999.0
# 920  Silicone Rubber Earbuds Tips, Eartips, Earpads...         999.0
# 644  Sounce Spiral Charger Cable Protector Data Cab...         999.0
# 407  Sounce Spiral Charger Cable Protector Data Cab...         999.0
#
#      discounted_price  discount_percentage
# 695             294.0                 94.0
# 372            1799.0                 91.0
# 380            1799.0                 91.0
# ...

# %%
analysis_df["calculated_discount"] = (
    analysis_df["amount_saved"]/analysis_df["actual_price"]
)*100

# %%
analysis_df[["actual_price","discounted_price","discount_percentage","calculated_discount"]]
# Out:
#       actual_price  discounted_price  discount_percentage  calculated_discount
# 0           1099.0             399.0                 64.0            63.694268
# 1            349.0             199.0                 43.0            42.979943
# 2           1899.0             199.0                 90.0            89.520800
# 3            699.0             329.0                 53.0            52.932761
# 4            399.0             154.0                 61.0            61.403509
# ...            ...               ...                  ...                  ...
# 1460         919.0             379.0                 59.0            58.759521
# 1461        3045.0            2280.0                 25.0            25.123153
# 1462        3080.0            2219.0                 28.0            27.954545
# 1463        1890.0            1399.0                 26.0            25.978836
# 1464        3690.0            2863.0                 22.0            22.411924
#
# [1465 rows x 4 columns]

# %%
analysis_df["discount_diff"] = (
    analysis_df["discount_percentage"] - analysis_df["calculated_discount"]
)
analysis_df["discount_diff"].abs().describe()
# Out:
# count    1464.000000
# mean        0.209343
# std         0.160968
# min         0.000000
# 25%         0.061037
# 50%         0.184400
# 75%         0.353847
# max         0.500000
# Name: discount_diff, dtype: float64

# %%
# checking which row have most diference betwwe descounted_percentage calculated_discount 
analysis_df.loc[
    analysis_df["discount_diff"].abs().idxmax(),
    ["actual_price","discounted_price","discount_percentage","calculated_discount","discount_diff"]
    ]
# Out:
# actual_price           600.0
# discounted_price       249.0
# discount_percentage     59.0
# calculated_discount     58.5
# discount_diff            0.5
# Name: 817, dtype: object

# %%
analysis_df["price_segment"] = pd.cut(
    analysis_df["discounted_price"],
    bins=[0,500,2000,10000, float("inf")],
    labels=["Budget","Mid-Range","Premium","Luxury"]
)

# %%
analysis_df["price_segment"].value_counts()
# Out:
# price_segment
# Budget       575
# Mid-Range    527
# Premium      240
# Luxury       122
# Name: count, dtype: int64

# %%
analysis_df.groupby("price_segment").agg(
    product_count = ("product_id","count"),
    avg_rating = ("rating","mean"),
    avg_discount = ("discount_percentage","mean")
)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7184\3805348207.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   analysis_df.groupby("price_segment").agg(
#                product_count  avg_rating  avg_discount
# price_segment
# Budget                   575    4.074261     55.763478
# Mid-Range                527    4.092789     46.017078
# Premium                  240    4.107950     39.729167
# Luxury                   122    4.195082     32.401639

# %%
analysis_df.sort_values(
    "rating_count",
    ascending=False
)[
    ["product_name","price_segment","rating","rating_count"]
    ].head(10)
# Out:
#                                           product_name price_segment  rating  \
# 47   Amazon Basics High-Speed HDMI Cable, 6 Feet - ...        Budget     4.4
# 65   Amazon Basics High-Speed HDMI Cable, 6 Feet (2...        Budget     4.4
# 12   AmazonBasics Flexible Premium HDMI Cable (Blac...        Budget     4.4
# 684  AmazonBasics Flexible Premium HDMI Cable (Blac...        Budget     4.4
# 400  boAt Bassheads 100 in Ear Wired Earphones with...        Budget     4.1
# 352  boAt Bassheads 100 in Ear Wired Earphones with...        Budget     4.1
# 584  boAt BassHeads 100 in-Ear Wired Headphones wit...        Budget     4.1
# 371  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...       Premium     4.1
# 370  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...       Premium     4.1
# 566  Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Sto...       Premium     4.1
#
#      rating_count
# 47       426973.0
# 65       426973.0
# 12       426973.0
# 684      426972.0
# 400      363713.0
# ...

# %%
analysis_df[
    analysis_df["rating_count"] == analysis_df["rating_count"].max()
    ][
    ["product_id","product_name","category","actual_price","discounted_price","rating","rating_count"]
    ]
# Out:
#     product_id                                       product_name  \
# 12  B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 47  B014I8SSD0  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...
# 65  B014I8SX4Y  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...
#
#                                              category  actual_price  \
# 12  Electronics|HomeTheater,TV&Video|Accessories|C...         700.0
# 47  Electronics|HomeTheater,TV&Video|Accessories|C...         475.0
# 65  Electronics|HomeTheater,TV&Video|Accessories|C...        1400.0
#
#     discounted_price  rating  rating_count
# 12             219.0     4.4      426973.0
# 47             309.0     4.4      426973.0
# 65             309.0     4.4      426973.0

# %%
# it give counts of rating that have rating more than 1lakh 
(analysis_df["rating_count"] > 100000).sum()
# Out:
# np.int64(47)

# %%
# it give percentage of rating that have rating more than 1lakh 

(analysis_df["rating_count"] > 100000).mean() * 100
# Out:
# np.float64(3.2081911262798632)

# %%
# It give median of rating count by price segments
analysis_df.groupby("price_segment")["rating_count"].median()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7184\2036576643.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   analysis_df.groupby("price_segment")["rating_count"].median()
# price_segment
# Budget        3066.0
# Mid-Range     7619.0
# Premium       4137.5
# Luxury       11976.0
# Name: rating_count, dtype: float64

# %%
analysis_df[
    ["discounted_price","rating_count"]
    ].corr()
# Out:
#                   discounted_price  rating_count
# discounted_price          1.000000     -0.027296
# rating_count             -0.027296      1.000000

# %%
# Give row that have rating and rating count more than and equals to 4.5 and 100000
analysis_df[
    (analysis_df["rating"] >=4.5) & (analysis_df["rating_count"] >= 100000)
    ][
    ["product_id","product_name","discounted_price","rating","rating_count"]
    ].sort_values("rating_count",ascending=False).head(10)
# Out:
#      product_id                                       product_name  \
# 864  B09X7DY7Q4  SanDisk Extreme SD UHS I 64GB Card for 4K Vide...
# 40   B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...
# 852  B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...
#
#      discounted_price  rating  rating_count
# 864             939.0     4.5      205052.0
# 40              209.0     4.5      107687.0
# 852             209.0     4.5      107686.0

# %%
# Give row that have rating less than & equals to 3.5 and rating count more than & equals to 10000
analysis_df[
    (analysis_df["rating"] <= 3.5) & (analysis_df["rating_count"] >= 10000)
    ][
    ["product_id","product_name","discounted_price","rating","rating_count"]
    ].sort_values("rating_count",ascending=False).head(10)
# Out:
#      product_id                                       product_name  \
# 415  B085W8CFLH  PTron Tangent Lite Bluetooth 5.0 Earphones wit...
# 597  B07T5DKR5D  ZEBRONICS Zeb-Bro in Ear Wired Earphones with ...
# 873  B08D9NDZ1Y  HP Deskjet 2331 Colour Printer, Scanner and Co...
# 629  B087FXHB6J  Zebronics Zeb-Companion 107 USB Wireless Keybo...
# 645  B00MFPCY5C  GIZGA essentials Universal Silicone Keyboard P...
# 867  B09ND94ZRG  Boult Audio Airbass Propods X TWS Bluetooth Tr...
# 921  B01EJ5MM5M  Canon PIXMA MG2577s All-in-One Inkjet Colour P...
# 627  B08YDFX7Y1  ZEBRONICS Zeb-Dash Plus 2.4GHz High Precision ...
#
#      discounted_price  rating  rating_count
# 415             599.0     3.5       83996.0
# 597             149.0     3.5       21764.0
# 873            3999.0     3.5       21762.0
# 629             699.0     3.5       15295.0
# 645              39.0     3.5       15233.0
# 867            1099.0     3.5       12966.0
# 921            3498.0     3.4       12185.0
# ...

# %%
# Give Percentiles of Rating counts
analysis_df["rating_count"].describe(
    percentiles=[0.25,0.50,0.75,0.90,0.95,0.99]
)
# Out:
# count      1463.000000
# mean      18295.541353
# std       42753.864952
# min           2.000000
# 25%        1186.000000
# 50%        5179.000000
# 75%       17336.500000
# 90%       39555.000000
# 95%       74976.900000
# 99%      197325.560000
# max      426973.000000
# Name: rating_count, dtype: float64

# %%
# Making new column "Popularity Level" Acorrding percentiles comes
analysis_df["popularity_level"] = pd.cut(
    analysis_df["rating_count"],
    bins = [0,5179,17336.5,39555,float("inf")],
    labels = ["low","Medium","High","Very High"]
)

analysis_df["popularity_level"].value_counts()
# Out:
# popularity_level
# low          733
# Medium       364
# High         219
# Very High    147
# Name: count, dtype: int64

# %%
# give rating more and equals to 4.5 and popularity level is in high and very high
analysis_df[
    (analysis_df["rating"] >= 4.5) & (analysis_df["popularity_level"].isin(["High","Very High"]))
    ][
    [ 
        "product_id",
        "product_name",
        "discounted_price",
        "rating",
        "rating_count",
        "popularity_level"
    ]
    ].sort_values(["rating","rating_count"],ascending=[False,False]).head(15)
# Out:
#       product_id                                       product_name  \
# 1145  B0BR4F878Q  Swiffer Instant Electric Water Heater Faucet T...
# 820   B01J1CFO5I  Redgear MP35 Speed-Type Gaming Mousepad (Black...
# 447   B095RTJH1M  Spigen EZ Fit Tempered Glass Screen Protector ...
# 864   B09X7DY7Q4  SanDisk Extreme SD UHS I 64GB Card for 4K Vide...
# 40    B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...
# 852   B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...
# 810   B07G3YNLJB  Crucial BX500 240GB 3D NAND SATA 6.35 cm (2.5-...
# 212   B00NH13Q8W  AmazonBasics USB 2.0 Extension Cable for Perso...
# 30    B00NH11PEY  AmazonBasics USB 2.0 - A-Male to A-Female Exte...
# 802   B00NH11PEY  AmazonBasics USB 2.0 - A-Male to A-Female Exte...
# 734   B004IO5BMQ  Logitech M235 Wireless Mouse, 1000 DPI Optical...
# 625   B08ZJDWTJ1  Seagate Expansion 1TB External HDD - USB 3.0 f...
# 815   B094QZLJQ6  Seagate One Touch 2TB External HDD with Passwo...
# ...

# %%
# Making a new columns "Rating normalized"
analysis_df["rating_normalized"] = (
    (analysis_df["rating"] - analysis_df["rating"].min()) /
    (analysis_df["rating"].max() - analysis_df["rating"].min())
)
analysis_df["rating_normalized"].describe()
# Out:
# count    1464.000000
# mean        0.698862
# std         0.097225
# min         0.000000
# 25%         0.666667
# 50%         0.700000
# 75%         0.766667
# max         1.000000
# Name: rating_normalized, dtype: float64

# %%
# Making new column "Rating count Normalized" 
analysis_df["rating_count_normalized"] = (
    (analysis_df["rating_count"] - analysis_df["rating_count"].min()) /
    (analysis_df["rating_count"].max() - analysis_df["rating_count"].min())
)

analysis_df["rating_count_normalized"].describe()
# Out:
# count    1463.000000
# mean        0.042845
# std         0.100133
# min         0.000000
# 25%         0.002773
# 50%         0.012125
# 75%         0.040599
# max         1.000000
# Name: rating_count_normalized, dtype: float64

# %%
# Making new column "Product score" 

analysis_df["product_score"] = (
    0.7 * analysis_df["rating_normalized"] +
    0.3 * analysis_df["rating_count_normalized"] 
)

# %%
analysis_df[
    [
        "product_id",
        "product_name",
        "rating",
        "rating_count",
        "rating_normalized",
        "rating_count_normalized",
        "product_score"
    ]
    ].sort_values("product_score",ascending=False).head(10)
# Out:
#      product_id                                       product_name  rating  \
# 12   B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...     4.4
# 47   B014I8SSD0  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...     4.4
# 65   B014I8SX4Y  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...     4.4
# 684  B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...     4.4
# 352  B07GPXXNNG  boAt Bassheads 100 in Ear Wired Earphones with...     4.1
# 400  B07GQD4K6L  boAt Bassheads 100 in Ear Wired Earphones with...     4.1
# 584  B071Z8M4KX  boAt BassHeads 100 in-Ear Wired Headphones wit...     4.1
# 864  B09X7DY7Q4  SanDisk Extreme SD UHS I 64GB Card for 4K Vide...     4.5
# 588  B005FYNT3G          SanDisk Cruzer Blade 32GB USB Flash Drive     4.3
# 371  B09GFLXVH9  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...     4.1
#
#      rating_count  rating_normalized  rating_count_normalized  product_score
# ...

# %%
import numpy as np
analysis_df["rating_count_log"] = np.log1p(
    analysis_df["rating_count"]
)

analysis_df[
    ["rating_count","rating_count_log"]
    ].describe()
# Out:
#         rating_count  rating_count_log
# count    1463.000000       1463.000000
# mean    18295.541353          8.302841
# std     42753.864952          2.027431
# min         2.000000          1.098612
# 25%      1186.000000          7.079176
# 50%      5179.000000          8.552560
# 75%     17336.500000          9.760627
# max    426973.000000         12.964478

# %%
analysis_df["popularity_normalized"] = (
    (analysis_df["rating_count_log"] - analysis_df["rating_count_log"].min()) /
    (analysis_df["rating_count_log"].max() - analysis_df["rating_count_log"].min())
)
analysis_df["popularity_normalized"].describe()
# Out:
# count    1463.000000
# mean        0.607139
# std         0.170862
# min         0.000000
# 25%         0.504014
# 50%         0.628184
# 75%         0.729994
# max         1.000000
# Name: popularity_normalized, dtype: float64

# %%
analysis_df[
    ["product_id","product_name","category","actual_price","discounted_price","rating","rating_count"]
    ].sort_values("rating_count",ascending=False).head(10)
# Out:
#      product_id                                       product_name  \
# 47   B014I8SSD0  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...
# 65   B014I8SX4Y  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...
# 12   B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 684  B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 400  B07GQD4K6L  boAt Bassheads 100 in Ear Wired Earphones with...
# 352  B07GPXXNNG  boAt Bassheads 100 in Ear Wired Earphones with...
# 584  B071Z8M4KX  boAt BassHeads 100 in-Ear Wired Headphones wit...
# 371  B09GFLXVH9  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...
# 370  B09GFPVD9Y  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...
# 566  B09GFPN6TP  Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Sto...
#
#                                               category  actual_price  \
# 47   Electronics|HomeTheater,TV&Video|Accessories|C...         475.0
# 65   Electronics|HomeTheater,TV&Video|Accessories|C...        1400.0
# ...

# %%
analysis_df[
    (analysis_df["rating"] >= 4.5) & (analysis_df["rating_count"] >= 10000)
    ][
        ["product_id","product_name","category","actual_price","discounted_price","rating","rating_count"]
    ].sort_values(["rating_count","rating"],ascending=[False,False]).head(10)
# Out:
#       product_id                                       product_name  \
# 864   B09X7DY7Q4  SanDisk Extreme SD UHS I 64GB Card for 4K Vide...
# 40    B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...
# 852   B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...
# 810   B07G3YNLJB  Crucial BX500 240GB 3D NAND SATA 6.35 cm (2.5-...
# 212   B00NH13Q8W  AmazonBasics USB 2.0 Extension Cable for Perso...
# 30    B00NH11PEY  AmazonBasics USB 2.0 - A-Male to A-Female Exte...
# 802   B00NH11PEY  AmazonBasics USB 2.0 - A-Male to A-Female Exte...
# 734   B004IO5BMQ  Logitech M235 Wireless Mouse, 1000 DPI Optical...
# 1145  B0BR4F878Q  Swiffer Instant Electric Water Heater Faucet T...
# 625   B08ZJDWTJ1  Seagate Expansion 1TB External HDD - USB 3.0 f...
#
#                                                category  actual_price  \
# 864         Electronics|Accessories|MemoryCards|MicroSD        1800.0
# 40    Computers&Accessories|Accessories&Peripherals|...         695.0
# ...

# %%
analysis_df[
    (analysis_df["rating"] <= 3.5) & (analysis_df["rating_count"] >= 10000)
    ][
        ["product_id","product_name","category","actual_price","discounted_price","rating","rating_count"]
    ].sort_values("rating",ascending=True).head(10)
# Out:
#      product_id                                       product_name  \
# 921  B01EJ5MM5M  Canon PIXMA MG2577s All-in-One Inkjet Colour P...
# 415  B085W8CFLH  PTron Tangent Lite Bluetooth 5.0 Earphones wit...
# 627  B08YDFX7Y1  ZEBRONICS Zeb-Dash Plus 2.4GHz High Precision ...
# 597  B07T5DKR5D  ZEBRONICS Zeb-Bro in Ear Wired Earphones with ...
# 629  B087FXHB6J  Zebronics Zeb-Companion 107 USB Wireless Keybo...
# 645  B00MFPCY5C  GIZGA essentials Universal Silicone Keyboard P...
# 867  B09ND94ZRG  Boult Audio Airbass Propods X TWS Bluetooth Tr...
# 873  B08D9NDZ1Y  HP Deskjet 2331 Colour Printer, Scanner and Co...
#
#                                               category  actual_price  \
# 921  Computers&Accessories|Printers,Inks&Accessorie...       3875.00
# 415  Electronics|Headphones,Earbuds&Accessories|Hea...       1800.00
# 627  Computers&Accessories|Accessories&Peripherals|...        449.00
# 597  Electronics|Headphones,Earbuds&Accessories|Hea...        399.00
# ...

# %%
analysis_df["customer_saves"] = analysis_df["actual_price"] - analysis_df["discounted_price"]
analysis_df[["product_id","product_name","actual_price","discounted_price","customer_saves"]].sort_values("customer_saves",ascending=False).head(10)
# Out:
#       product_id                                       product_name  \
# 249   B09WN3SRC7  Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...
# 1182  B08GJ57MKL  Coway Professional Air Purifier for Home, Long...
# 568   B08VB57558  Samsung Galaxy S20 FE 5G (Cloud Navy, 8GB RAM,...
# 150   B0BB3CBFBM  VU 138 cm (55 inches) Premium Series 4K Ultra ...
# 1354  B09NS5TKPN  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 283   B0B3XXSB1K  LG 139 cm (55 inches) 4K Ultra HD Smart LED TV...
# 1306  B0B19VJXQZ  ECOVACS DEEBOT N8 2-in-1 Robotic Vacuum Cleane...
# 255   B0BC8BQ432  VU 164 cm (65 inches) The GloLED Series 4K Sma...
# 108   B0B9XLX8VR  VU 139 cm (55 inches) The GloLED Series 4K Sma...
# 323   B08FD2VSD9  TCL 108 cm (43 inches) 4K Ultra HD Certified A...
#
#       actual_price  discounted_price  customer_saves
# 249       139900.0           77990.0         61910.0
# 1182       59900.0           14400.0         45500.0
# 568        74999.0           37990.0         37009.0
# ...

# %%
analysis_df[
    ["product_id","product_name","category","actual_price","discounted_price","discount_percentage"]
    ].sort_values("discount_percentage",ascending=False).head(10)
# Out:
#      product_id                                       product_name  \
# 695  B097C564GC  rts [2 Pack] Mini USB C Type C Adapter Plug, T...
# 372  B0BF4YBLPX  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 380  B0BF54LXW6  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 364  B0BF54972T  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 368  B0BF563HB4  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 334  B0BF57RN3K  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 557  B0BBW521YC  LAPSTER 12pcs Spiral Cable Protectors for Char...
# 920  B08X77LM8C  Silicone Rubber Earbuds Tips, Eartips, Earpads...
# 644  B085HY1DGR  Sounce Spiral Charger Cable Protector Data Cab...
# 407  B085HY1DGR  Sounce Spiral Charger Cable Protector Data Cab...
#
#                                               category  actual_price  \
# 695  Computers&Accessories|Accessories&Peripherals|...        4999.0
# 372        Electronics|WearableTechnology|SmartWatches       19999.0
# ...

# %%
analysis_df[["actual_price","rating"]].corr()
# Out:
#               actual_price    rating
# actual_price      1.000000  0.121642
# rating            0.121642  1.000000

# %%
analysis_df.groupby("category")["rating"].mean().sort_values(ascending=False).head(10)
# Out:
# category
# Computers&Accessories|Tablets                                                                 4.6
# Computers&Accessories|NetworkingDevices|NetworkAdapters|PowerLANAdapters                      4.5
# Electronics|Cameras&Photography|Accessories|Film                                              4.5
# Computers&Accessories|Components|Memory                                                       4.5
# Electronics|HomeAudio|MediaStreamingDevices|StreamingClients                                  4.5
# OfficeProducts|OfficeElectronics|Calculators|Basic                                            4.5
# HomeImprovement|Electrical|CordManagement                                                     4.5
# Home&Kitchen|Kitchen&HomeAppliances|Coffee,Tea&Espresso|CoffeePresses                         4.5
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|SmallApplianceParts&Accessories    4.5
# ...

# %%
result = analysis_df.groupby("category").agg(
    unique_product = ("product_id","nunique"),
    avg_rating = ("rating","mean")
)
result[result["unique_product"]>=10].sort_values(by = "avg_rating",ascending=False).head(10)
# Out:
#                                                     unique_product  avg_rating
# category
# Electronics|Accessories|MemoryCards|MicroSD                     10    4.330769
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitche...              11    4.290909
# Computers&Accessories|Accessories&Peripherals|K...              24    4.287500
# Computers&Accessories|ExternalDevices&DataStora...              10    4.260000
# Electronics|HomeTheater,TV&Video|Accessories|Ca...              21    4.254167
# Electronics|HomeTheater,TV&Video|Televisions|Sm...              60    4.209524
# Home&Kitchen|Kitchen&HomeAppliances|WaterPurifi...              12    4.175000
# Electronics|Mobiles&Accessories|MobileAccessori...              10    4.160000
# Computers&Accessories|Accessories&Peripherals|C...             160    4.151931
# Electronics|Mobiles&Accessories|MobileAccessori...              15    4.143750

# %%
analysis_df["main_category"] = analysis_df["category"].str.split("|").str[0]
analysis_df.groupby("main_category")["discounted_price"].mean().sort_values(ascending=False).head(10)
# Out:
# main_category
# Electronics              5965.887833
# Car&Motorbike            2339.000000
# Home&Kitchen             2330.615647
# Health&PersonalCare       899.000000
# Computers&Accessories     843.742522
# MusicalInstruments        638.000000
# HomeImprovement           337.000000
# OfficeProducts            301.580645
# Toys&Games                150.000000
# Name: discounted_price, dtype: float64

# %%
# Which main categories have at least 50 unique products AND the highest average rating?
result = analysis_df.groupby("main_category").agg(
    unique_product = ("product_id","nunique"),
    avg_rating = ("rating","mean")
)
result[result["unique_product"]>=50].sort_values(by = "avg_rating",ascending=False).head(10)
# Out:
#                        unique_product  avg_rating
# main_category
# Computers&Accessories             374    4.154967
# Electronics                       490    4.081749
# Home&Kitchen                      448    4.040716

# %%
analysis_df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'main_category', 'amount_saved', 'calculated_discount', 'discount_diff',
#        'price_segment', 'popularity_level', 'rating_normalized',
#        'rating_count_normalized', 'product_score', 'rating_count_log',
#        'popularity_normalized', 'customer_saves'],
#       dtype='object')

# %%
# Which main category gives the highest average amount of money saved by customers?
analysis_df.groupby("main_category")["customer_saves"].mean().sort_values(ascending=False).head(10)
# Out:
# main_category
# Electronics              4161.423954
# Home&Kitchen             1831.458013
# Car&Motorbike            1661.000000
# Health&PersonalCare      1001.000000
# Computers&Accessories     841.395265
# MusicalInstruments        709.000000
# HomeImprovement           462.000000
# OfficeProducts             95.612903
# Toys&Games                  0.000000
# Name: customer_saves, dtype: float64

# %%
analysis_df[["discount_percentage","rating"]].corr()
# Out:
#                      discount_percentage    rating
# discount_percentage             1.000000 -0.155375
# rating                         -0.155375  1.000000

# %%
# Find products that have good ratings, but are also reasonably popular.
analysis_df[
    (analysis_df["rating"] >= 4.5) & (analysis_df["rating_count"] >= 50000)
    ][
        ["product_id","product_name","rating","rating_count","discounted_price"]
        ].sort_values("rating_count",ascending=False).head(20)
# Out:
#       product_id                                       product_name  rating  \
# 864   B09X7DY7Q4  SanDisk Extreme SD UHS I 64GB Card for 4K Vide...     4.5
# 40    B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...     4.5
# 852   B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...     4.5
# 810   B07G3YNLJB  Crucial BX500 240GB 3D NAND SATA 6.35 cm (2.5-...     4.5
# 212   B00NH13Q8W  AmazonBasics USB 2.0 Extension Cable for Perso...     4.5
# 30    B00NH11PEY  AmazonBasics USB 2.0 - A-Male to A-Female Exte...     4.5
# 802   B00NH11PEY  AmazonBasics USB 2.0 - A-Male to A-Female Exte...     4.5
# 734   B004IO5BMQ  Logitech M235 Wireless Mouse, 1000 DPI Optical...     4.5
# 1145  B0BR4F878Q  Swiffer Instant Electric Water Heater Faucet T...     4.8
# 625   B08ZJDWTJ1  Seagate Expansion 1TB External HDD - USB 3.0 f...     4.5
# 815   B094QZLJQ6  Seagate One Touch 2TB External HDD with Passwo...     4.5
#
#       rating_count  discounted_price
# ...

# %%
# Do expensive products receive more ratings?
analysis_df[["discounted_price","rating_count"]].corr()
# Out:
#                   discounted_price  rating_count
# discounted_price          1.000000     -0.027296
# rating_count             -0.027296      1.000000

# %%
# Which products give customers both a high rating AND a high discount?
analysis_df[
    (analysis_df["rating"] >= 4.5) & (analysis_df["discount_percentage"] >= 50)
    ][
        ["product_id","product_name","rating","rating_count","discounted_price","discount_percentage"]
        ].sort_values("discount_percentage",ascending=False).head(20)
# Out:
#       product_id                                       product_name  rating  \
# 476   B07Q4QV1DL  ELV Aluminum Adjustable Mobile Phone Foldable ...     4.5
# 88    B0BMXMLSMM  Lapster 65W compatible for OnePlus Dash Warp C...     4.5
# 174   B0BP7XLX48  Syncwire LTG to USB Cable for Fast Charging Co...     5.0
# 114   B09TT6BFDX  Cotbolt Silicone Protective Case Cover for LG ...     4.5
# 1018  B0BMXMLSMM  Lapster 65W compatible for OnePlus Dash Warp C...     4.5
# 1416  B0BJ6P3LSK  Aqua d pure Active Copper 12-L RO+UV Water Fil...     4.5
# 1289  B0BJ966M5K  Aquadpure Copper + Mineral RO+UV+UF 10 to 12 L...     4.6
# 580   B088ZFJY82  Elv Aluminium Adjustable Mobile Phone Foldable...     4.5
# 547   B0BMM7R92G  Noise_Colorfit Smart Watch Charger 2 Pin USB F...     4.5
# 324   B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...     5.0
# 520   B0B8CHJLWJ  Kyosei Advanced Tempered Glass Compatible with...     4.5
# ...

# %%
# Among products with at least 10,000 ratings, what is the average rating for each main category?
analysis_df[
    analysis_df["rating_count"] >= 10000
    ].groupby("main_category")["rating"].mean().sort_values(ascending=False)
# Out:
# main_category
# OfficeProducts           4.400000
# Toys&Games               4.300000
# Computers&Accessories    4.221622
# Electronics              4.121429
# Home&Kitchen             4.081928
# MusicalInstruments       3.900000
# Name: rating, dtype: float64

# %%
# Find products that are highly rated, highly popular, and offer a high discount.
analysis_df[
    (analysis_df["rating"] >= 4.5) & (analysis_df["rating_count"] >= 50000) & (analysis_df["discount_percentage"] >= 50)
    ][
    ["product_id","product_name","rating","rating_count","discount_percentage","discounted_price"]
    ].sort_values("rating_count",ascending=False).head(10)
# Out:
#      product_id                                       product_name  rating  \
# 40   B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...     4.5
# 852  B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...     4.5
# 212  B00NH13Q8W  AmazonBasics USB 2.0 Extension Cable for Perso...     4.5
# 30   B00NH11PEY  AmazonBasics USB 2.0 - A-Male to A-Female Exte...     4.5
# 802  B00NH11PEY  AmazonBasics USB 2.0 - A-Male to A-Female Exte...     4.5
#
#      rating_count  discount_percentage  discounted_price
# 40       107687.0                 70.0             209.0
# 852      107686.0                 70.0             209.0
# 212       74977.0                 63.0             299.0
# 30        74976.0                 73.0             199.0
# 802       74976.0                 73.0             199.0

# %%
analysis_df.groupby("main_category").agg(
    total_product = ("product_id","count"),
    avg_price = ("actual_price","mean"),
    avg_discount = ("discounted_price","mean"),
    avg_rating = ("rating","mean")
)
# Out:
#                        total_product     avg_price  avg_discount  avg_rating
# main_category
# Car&Motorbike                      1   4000.000000   2339.000000    3.800000
# Computers&Accessories            453   1683.623135    843.742522    4.154967
# Electronics                      526  10127.311787   5965.887833    4.081749
# Health&PersonalCare                1   1900.000000    899.000000    4.000000
# Home&Kitchen                     448   4162.073661   2330.615647    4.040716
# HomeImprovement                    2    799.000000    337.000000    4.250000
# MusicalInstruments                 2   1347.000000    638.000000    3.900000
# OfficeProducts                    31    397.193548    301.580645    4.309677
# Toys&Games                         1    150.000000    150.000000    4.300000

# %%
analysis_df["rating_count"].describe()
# Out:
# count      1463.000000
# mean      18295.541353
# std       42753.864952
# min           2.000000
# 25%        1186.000000
# 50%        5179.000000
# 75%       17336.500000
# max      426973.000000
# Name: rating_count, dtype: float64

# %%
Q1 = 1186
Q3 = 17336
IQR = Q3 - Q1
IQR
# Out:
# 16150

# %%
lower = Q1 - 1.5*(IQR)
upper = Q3 + 1.5*(IQR)
print(f"Lower : {lower} \nUpper : {upper}")
# Out:
# Lower : -23039.0
# Upper : 41561.0

# %%
outliers = analysis_df[
    analysis_df["rating_count"] >= 41561.25
    ]

outliers.shape
# Out:
# (141, 20)

# %%
141/len(analysis_df) * 100
# Out:
# 9.62457337883959

# %%
analysis_df["discounted_price"].hist(bins=40)
# Out:
# <Axes: >

# %%
analysis_df["discounted_price"].plot(kind="box")
# Out:
# <Axes: >

# %%
# Which main categories have the most products?
analysis_df["main_category"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='main_category'>

# %%
# Does product price have any visible relationship with rating?
analysis_df.plot(
    kind="scatter",
    x="discounted_price",
    y="rating"
)
# Out:
# <Axes: xlabel='discounted_price', ylabel='rating'>

# %%
category_price = (
    analysis_df.groupby("main_category")["discounted_price"].mean().sort_values(ascending = False)
)

category_price.plot(
    kind = "bar",
    figsize = (10, 5),
    title = "Average Discount Price By Main Category",
    xlabel = "main_category",
    ylabel = "Average Disocounted Price"
)
# Out:
# <Axes: title={'center': 'Average Discount Price By Main Category'}, xlabel='main_category', ylabel='Average Disocounted Price'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(
    analysis_df["discounted_price"],
    bins=40,
    kde=True
)

plt.title("Distribution of Discounted Prices")
plt.xlabel("Discounted Price")
plt.ylabel("Number Of Products")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(
    data = analysis_df,
    x = "rating_count",
    y = "rating",
    alpha = 0.5
)

plt.xscale("log")

plt.title("Rating Vs Popularity")
plt.xlabel("Rating Count")
plt.ylabel("Rating")
plt.show()
